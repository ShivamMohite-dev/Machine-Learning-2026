# %%
import pandas as pd

# %%
df = pd.read_csv('fortune.csv')
df.head(4)
# Out:
#    Unnamed: 0  Rank                   Company  \
# 0           0     1                   Walmart
# 1           1     2                Amazon.com
# 2           2     3                State Grid
# 3           3     4  China National Petroleum
#
#                           Industry              Address         City  \
# 0            General Merchandisers  702 S.W. Eighth St.  Bentonville
# 1  Internet Services and Retailing    410 Terry Ave. N.      Seattle
# 2                        Utilities   86 Xichang'an Ave.      Beijing
# 3               Petroleum Refining  9 Dongzhimen N. St.      Beijing
#
#   State / Country Postal Code Country Revenue (in millions, USD)  Employees  \
# 0        Arkansas       72716    U.S.                   $572,754    2300000
# 1      Washington       98109    U.S.                   $469,822    1608000
# 2           China      100031   China                   $460,617     871145
# 3           China      100007   China                   $411,693    1090345
#
#   Ticker          Website                  CEO
# 0    WMT  www.walmart.com  C. Douglas Mcmillon
# 1   AMZN   www.amazon.com      Andrew R. Jassy
# 2    NaN  www.sgcc.com.cn                  NaN
# 3    NaN  www.cnpc.com.cn           Li Fanrong

# %% [markdown]
# # Droping the 'Unnamed: 0' column

# %%
df = df.drop('Unnamed: 0',axis=1)

# %%
df.head(2)
# Out:
#    Rank     Company                         Industry              Address  \
# 0     1     Walmart            General Merchandisers  702 S.W. Eighth St.
# 1     2  Amazon.com  Internet Services and Retailing    410 Terry Ave. N.
#
#           City State / Country Postal Code Country Revenue (in millions, USD)  \
# 0  Bentonville        Arkansas       72716    U.S.                   $572,754
# 1      Seattle      Washington       98109    U.S.                   $469,822
#
#    Employees Ticker          Website                  CEO
# 0    2300000    WMT  www.walmart.com  C. Douglas Mcmillon
# 1    1608000   AMZN   www.amazon.com      Andrew R. Jassy

# %% [markdown]
# # Checking for any missing values in columns

# %%
#Option 1
df.isnull().sum()
# Out:
# Rank                            0
# Company                         0
# Industry                        0
# Address                         0
# City                            0
# State / Country                 0
# Postal Code                     0
# Country                         0
# Revenue (in millions, USD)      0
# Employees                       0
# Ticker                        187
# Website                         0
# CEO                            80
# dtype: int64

# %%
#Option 2
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Rank                        500 non-null    int64
#  1   Company                     500 non-null    object
#  2   Industry                    500 non-null    object
#  3   Address                     500 non-null    object
#  4   City                        500 non-null    object
#  5   State / Country             500 non-null    object
#  6   Postal Code                 500 non-null    object
#  7   Country                     500 non-null    object
#  8   Revenue (in millions, USD)  500 non-null    object
#  9   Employees                   500 non-null    int64
#  10  Ticker                      313 non-null    object
#  11  Website                     500 non-null    object
#  12  CEO                         420 non-null    object
# dtypes: int64(2), object(11)
# memory usage: 50.9+ KB

# %%
# 187 null values in 'Ticker'
# 80 null values in 'CEO'

# %% [markdown]
# # Finding out the number of unique industries

# %%
#Option 1
df['Industry'].unique().size
# Out:
# 57

# %%
#Option 2
INDUSTRIES = df.groupby('Industry')
INDUSTRIES.size().shape
# Out:
# (57,)

# %% [markdown]
# # How many industries in each country

# %%
def Details(country):
  mask = df['Country'] == country
  temp_df = df[mask]
  xp = temp_df['Industry'].size
  return f"Number of Industries in {country} : {xp}"

# %%
print(Details('China'))
print(Details('U.S.'))
print(Details('India'))
print(Details('Japan'))
# Out:
# Number of Industries in China : 136
# Number of Industries in U.S. : 124
# Number of Industries in India : 9
# Number of Industries in Japan : 47

# %% [markdown]
# # Filtering all the companies in U.S.
# #AND
# # filtering the dataset based on condition that Revenue of the company has to be greater than $450,000

# %%
mask1 = df['Country'] == 'U.S.'
df[mask1].head()
# Out:
#     Rank             Company                                  Industry  \
# 0      1             Walmart                     General Merchandisers
# 1      2          Amazon.com           Internet Services and Retailing
# 6      7               Apple               Computers, Office Equipment
# 9     10          CVS Health  Health Care: Pharmacy and Other Services
# 10    11  UnitedHealth Group   Health Care: Insurance and Managed Care
#
#                 Address         City State / Country Postal Code Country  \
# 0   702 S.W. Eighth St.  Bentonville        Arkansas       72716    U.S.
# 1     410 Terry Ave. N.      Seattle      Washington       98109    U.S.
# 6      1 Apple Park Way    Cupertino      California       95014    U.S.
# 9             1 CVS Dr.   Woonsocket    Rhode Island       02895    U.S.
# 10     9900 Bren Rd. E.   Minnetonka       Minnesota       55343    U.S.
#
#    Revenue (in millions, USD)  Employees Ticker                    Website  \
# 0                    $572,754    2300000    WMT            www.walmart.com
# 1                    $469,822    1608000   AMZN             www.amazon.com
# 6                    $365,817     154000   AAPL              www.apple.com
# 9                    $292,111     258000    CVS          www.cvshealth.com
# 10                   $287,597     350000    UNH  www.unitedhealthgroup.com
#
#                     CEO
# 0   C. Douglas Mcmillon
# 1       Andrew R. Jassy
# 6       Timothy D. Cook
# 9        Karen S. Lynch
# 10      Andrew P. Witty

# %%
mask2 = df['Revenue (in millions, USD)'] > '$450,000'
df[mask2].head()
# Out:
#     Rank                      Company  \
# 0      1                      Walmart
# 1      2                   Amazon.com
# 2      3                   State Grid
# 94    95        Electricité de France
# 95    96  Huawei Investment & Holding
#
#                                     Industry                 Address  \
# 0                      General Merchandisers     702 S.W. Eighth St.
# 1            Internet Services and Retailing       410 Terry Ave. N.
# 2                                  Utilities      86 Xichang'an Ave.
# 94                                 Utilities     22-30 Ave.de Wagram
# 95  Network & Other Communications Equipment  Huawei Industrial Base
#
#            City State / Country Postal Code Country  \
# 0   Bentonville        Arkansas       72716    U.S.
# 1       Seattle      Washington       98109    U.S.
# 2       Beijing           China      100031   China
# 94        Paris          France       75008  France
# 95     Shenzhen           China      518129   China
#
#    Revenue (in millions, USD)  Employees Ticker          Website  \
# 0                    $572,754    2300000    WMT  www.walmart.com
# 1                    $469,822    1608000   AMZN   www.amazon.com
# 2                    $460,617     871145    NaN  www.sgcc.com.cn
# 94                    $99,861     163423  ECIFY       www.edf.fr
# 95                    $98,725     195000    NaN   www.huawei.com
#
#                     CEO
# 0   C. Douglas Mcmillon
# 1       Andrew R. Jassy
# 2                   NaN
# 94    Jean-Bernard Levy
# 95            Ma Qianli

# %% [markdown]
# # Filtering the dataset on condition : Companies having employees greater than 20,00,000 and country being U.S.

# %%
mask3 = df['Employees'] > 100000
mask4 = df['Country'] == 'U.S.'

# %%
df[mask3 & mask4].head()
# Out:
#     Rank             Company                                  Industry  \
# 0      1             Walmart                     General Merchandisers
# 1      2          Amazon.com           Internet Services and Retailing
# 6      7               Apple               Computers, Office Equipment
# 9     10          CVS Health  Health Care: Pharmacy and Other Services
# 10    11  UnitedHealth Group   Health Care: Insurance and Managed Care
#
#                 Address         City State / Country Postal Code Country  \
# 0   702 S.W. Eighth St.  Bentonville        Arkansas       72716    U.S.
# 1     410 Terry Ave. N.      Seattle      Washington       98109    U.S.
# 6      1 Apple Park Way    Cupertino      California       95014    U.S.
# 9             1 CVS Dr.   Woonsocket    Rhode Island       02895    U.S.
# 10     9900 Bren Rd. E.   Minnetonka       Minnesota       55343    U.S.
#
#    Revenue (in millions, USD)  Employees Ticker                    Website  \
# 0                    $572,754    2300000    WMT            www.walmart.com
# 1                    $469,822    1608000   AMZN             www.amazon.com
# 6                    $365,817     154000   AAPL              www.apple.com
# 9                    $292,111     258000    CVS          www.cvshealth.com
# 10                   $287,597     350000    UNH  www.unitedhealthgroup.com
#
#                     CEO
# 0   C. Douglas Mcmillon
# 1       Andrew R. Jassy
# 6       Timothy D. Cook
# 9        Karen S. Lynch
# 10      Andrew P. Witty

# %% [markdown]
# # Sorting the dataset based on country and revenue

# %%
df.sort_values('Country')
# Out:
#      Rank                          Company  \
# 271   272                 Woolworths Group
# 492   493                      Coles Group
# 212   213                        BHP Group
# 329   330                        OMV Group
# 499   500                          Umicore
# ..    ...                              ...
# 144   145                            Intel
# 142   143                          PepsiCo
# 140   141                        Citigroup
# 167   168  International Business Machines
# 0       1                          Walmart
#
#                                          Industry  \
# 271                            Food & Drug Stores
# 492                            Food & Drug Stores
# 212                  Mining, Crude-Oil Production
# 329                            Petroleum Refining
# 499                                     Chemicals
# ..                                            ...
# 144  Semiconductors & Other Electronic Components
# 142                        Food Consumer Products
# 140                 Banks: Commercial and Savings
# 167               Information Technology Services
# 0                           General Merchandisers
#
#                           Address           City State / Country Postal Code  \
# 271              1 Woolworths Way    Bella Vista       Australia       02153
# 492                800 Toorak Rd.  Hawthorn East       Australia       03123
# 212               171 Collins St.      Melbourne       Australia       03000
# 329              Trabrennstr. 6-8         Vienna         Austria       01020
# 499  Rue du Marais 31 Broekstraat       Brussels         Belgium       01000
# ..                            ...            ...             ...         ...
# 144    2200 Mission College Blvd.    Santa Clara      California       95054
# 142         700 Anderson Hill Rd.       Purchase        New York       10577
# 140             388 Greenwich St.       New York        New York       10013
# 167             1 New Orchard Rd.         Armonk        New York       10504
# 0             702 S.W. Eighth St.    Bentonville        Arkansas       72716
#
#        Country Revenue (in millions, USD)  Employees Ticker  \
# 271  Australia                    $50,211     210067  WOLWF
# 492  Australia                    $29,056     120000  CLEGF
# 212  Australia                    $60,817      34478    BHP
# 329    Austria                    $42,038      22434  OMVKY
# 499    Belgium                    $28,650      11050  UMICY
# ..         ...                        ...        ...    ...
# 144       U.S.                    $79,024     121100   INTC
# 142       U.S.                    $79,474     309000    PEP
# 140       U.S.                    $79,865     221768      C
# 167       U.S.                    $72,344     297800    IBM
# 0         U.S.                   $572,754    2300000    WMT
#
#                         Website                   CEO
# 271  www.woolworthsgroup.com.au         Brad Banducci
# 492       www.colesgroup.com.au           Steven Cain
# 212                 www.bhp.com            Mike Henry
# 329                 www.omv.com          Alfred Stern
# 499             www.umicore.com     Mathias Miedreich
# ..                          ...                   ...
# 144               www.intel.com  Patrick P. Gelsinger
# 142             www.pepsico.com     Ramon L. Laguarta
# 140           www.citigroup.com           Jane Fraser
# 167                 www.ibm.com        Arvind Krishna
# 0               www.walmart.com   C. Douglas Mcmillon
#
# [500 rows x 13 columns]

# %%
# Step 1 : convering the Revenue column into numeric column by removing the '$' symbol from the values of it
df['Revenue (in millions, USD)'] =  df['Revenue (in millions, USD)'].str.replace(r'[\$,]', '', regex=True).astype(int)

# %%
df
# Out:
#      Rank                   Company                            Industry  \
# 0       1                   Walmart               General Merchandisers
# 1       2                Amazon.com     Internet Services and Retailing
# 2       3                State Grid                           Utilities
# 3       4  China National Petroleum                  Petroleum Refining
# 4       5             Sinopec Group                  Petroleum Refining
# ..    ...                       ...                                 ...
# 495   496                       DSV  Mail, Package and Freight Delivery
# 496   497                       ABB                Industrial Machinery
# 497   498    Mondelez International              Food Consumer Products
# 498   499                    Danone              Food Consumer Products
# 499   500                   Umicore                           Chemicals
#
#                           Address         City State / Country Postal Code  \
# 0             702 S.W. Eighth St.  Bentonville        Arkansas       72716
# 1               410 Terry Ave. N.      Seattle      Washington       98109
# 2              86 Xichang'an Ave.      Beijing           China      100031
# 3             9 Dongzhimen N. St.      Beijing           China      100007
# 4           22 Chaoyangmen N. St.      Beijing           China      100728
# ..                            ...          ...             ...         ...
# 495                Hovedgaden 630   Hedehusene         Denmark       02640
# 496           Affolternstrasse 44       Zurich     Switzerland       08050
# 497          905 W. Fulton Market      Chicago        Illinois       60607
# 498            17 Blvd. Haussmann        Paris          France       75009
# 499  Rue du Marais 31 Broekstraat     Brussels         Belgium       01000
#
#          Country  Revenue (in millions, USD)  Employees Ticker  \
# 0           U.S.                      572754    2300000    WMT
# 1           U.S.                      469822    1608000   AMZN
# 2          China                      460617     871145    NaN
# 3          China                      411693    1090345    NaN
# 4          China                      401314     542286    NaN
# ..           ...                         ...        ...    ...
# 495      Denmark                       28988      77958  DSDVY
# 496  Switzerland                       28945     104400    ABB
# 497         U.S.                       28720      79000   MDLZ
# 498       France                       28708      98105  DANOY
# 499      Belgium                       28650      11050  UMICY
#
#                            Website                  CEO
# 0                  www.walmart.com  C. Douglas Mcmillon
# 1                   www.amazon.com      Andrew R. Jassy
# 2                  www.sgcc.com.cn                  NaN
# 3                  www.cnpc.com.cn           Li Fanrong
# 4                  www.sinopec.com                  NaN
# ..                             ...                  ...
# 495                    www.dsv.com  Jens Bjørn Andersen
# 496                    www.abb.com     Bjoern Rosengren
# 497  www.mondelezinternational.com                  NaN
# 498                 www.danone.com       Emmanuel Faber
# 499                www.umicore.com    Mathias Miedreich
#
# [500 rows x 13 columns]

# %%
# step 2 :- Insert masking condition to filter dataset

mask5 = df['Revenue (in millions, USD)'] > 400000
masked_df = df[mask5]
masked_df
# Out:
#    Rank                   Company                         Industry  \
# 0     1                   Walmart            General Merchandisers
# 1     2                Amazon.com  Internet Services and Retailing
# 2     3                State Grid                        Utilities
# 3     4  China National Petroleum               Petroleum Refining
# 4     5             Sinopec Group               Petroleum Refining
# 5     6              Saudi Aramco     Mining, Crude-Oil Production
#
#                  Address         City State / Country Postal Code  \
# 0    702 S.W. Eighth St.  Bentonville        Arkansas       72716
# 1      410 Terry Ave. N.      Seattle      Washington       98109
# 2     86 Xichang'an Ave.      Beijing           China      100031
# 3    9 Dongzhimen N. St.      Beijing           China      100007
# 4  22 Chaoyangmen N. St.      Beijing           China      100728
# 5          P.O. Box 5000      Dhahran    Saudi Arabia       31311
#
#         Country  Revenue (in millions, USD)  Employees Ticker  \
# 0          U.S.                      572754    2300000    WMT
# 1          U.S.                      469822    1608000   AMZN
# 2         China                      460617     871145    NaN
# 3         China                      411693    1090345    NaN
# 4         China                      401314     542286    NaN
# 5  Saudi Arabia                      400399      68493    NaN
#
#            Website                  CEO
# 0  www.walmart.com  C. Douglas Mcmillon
# 1   www.amazon.com      Andrew R. Jassy
# 2  www.sgcc.com.cn                  NaN
# 3  www.cnpc.com.cn           Li Fanrong
# 4  www.sinopec.com                  NaN
# 5   www.aramco.com       Amin H. Nasser

# %% [markdown]
# # Groupby to find out total number of employees, average revenue, number of industries

# %%
def Country_Details(country):
  mask6 = df['Country'] == country
  temp_df = df[mask6]
  x = temp_df['Industry'].unique().size
  y = temp_df['Employees'].sum()
  z = temp_df['Revenue (in millions, USD)'].sum() / x
  print(f"Total employees :- {y}")
  print(f"Average revenue of Industries in {country} is : {z}")
  print(f"The total number of Industries in {country} : {x}")

# %%
Country_Details("U.S.")
# Out:
# Total employees :- 18718398
# Average revenue of Industries in U.S. is : 233693.54166666666
# The total number of Industries in U.S. : 48

# %% [markdown]
# # Feature Engineering : Generating a new column

# %%
temp = df
def myfunc(emp):
  if emp > 1000000:
    return 'Enormous'
  elif emp > 500000 and emp < 1000000:
    return 'Medium'
  else :
    return 'Small'


temp['Size cateogory'] = temp['Employees'].apply(myfunc)
temp.head(3)
# Out:
#    Rank     Company                         Industry              Address  \
# 0     1     Walmart            General Merchandisers  702 S.W. Eighth St.
# 1     2  Amazon.com  Internet Services and Retailing    410 Terry Ave. N.
# 2     3  State Grid                        Utilities   86 Xichang'an Ave.
#
#           City State / Country Postal Code Country  \
# 0  Bentonville        Arkansas       72716    U.S.
# 1      Seattle      Washington       98109    U.S.
# 2      Beijing           China      100031   China
#
#    Revenue (in millions, USD)  Employees Ticker          Website  \
# 0                      572754    2300000    WMT  www.walmart.com
# 1                      469822    1608000   AMZN   www.amazon.com
# 2                      460617     871145    NaN  www.sgcc.com.cn
#
#                    CEO         CEO_lastname Size Cateogory Size cateogory
# 0  C. Douglas Mcmillon  C. Douglas Mcmillon       Enormous       Enormous
# 1      Andrew R. Jassy      Andrew R. Jassy       Enormous       Enormous
# 2                  NaN                  NaN         Medium         Medium
