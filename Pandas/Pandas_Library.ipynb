# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('student_info.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   student_id        1000 non-null   object
#  1   name              1000 non-null   object
#  2   gender            1000 non-null   object
#  3   age               1000 non-null   int64
#  4   grade_level       1000 non-null   int64
#  5   math_score        1000 non-null   int64
#  6   reading_score     1000 non-null   int64
#  7   writing_score     1000 non-null   int64
#  8   attendance_rate   1000 non-null   float64
#  9   parent_education  1000 non-null   object
#  10  study_hours       1000 non-null   float64
#  11  internet_access   1000 non-null   object
#  12  lunch_type        1000 non-null   object
#  13  extra_activities  1000 non-null   object
#  14  final_result      1000 non-null   object
# dtypes: float64(2), int64(5), object(8)
# memory usage: 117.3+ KB

# %%
df.shape
# Out:
# (1000, 15)

# %%
df.head()
# Out:
#   student_id       name gender  age  grade_level  math_score  reading_score  \
# 0         S1  Student_1  Other   17           10          74             61
# 1         S2  Student_2   Male   17           12          99             70
# 2         S3  Student_3  Other   17            9          59             60
# 3         S4  Student_4  Other   17           12          70             88
# 4         S5  Student_5   Male   15            9          85             77
#
#    writing_score  attendance_rate parent_education  study_hours  \
# 0             90        94.660002         Master's     4.120192
# 1             91        93.173227       Bachelor's     2.886505
# 2             99        98.631098              PhD     1.909926
# 3             69        96.419620              PhD     1.664740
# 4             94        91.332105              PhD     2.330918
#
#   internet_access       lunch_type extra_activities final_result
# ...

# %%
temp_df1 = df[['name','attendance_rate','study_hours','final_result']]
temp_df1
# Out:
#              name  attendance_rate  study_hours final_result
# 0       Student_1        94.660002     4.120192         Fail
# 1       Student_2        93.173227     2.886505         Pass
# 2       Student_3        98.631098     1.909926         Fail
# 3       Student_4        96.419620     1.664740         Pass
# 4       Student_5        91.332105     2.330918         Pass
# ..            ...              ...          ...          ...
# 995   Student_996        94.127440     2.212263         Fail
# 996   Student_997        86.911592     3.552898         Fail
# 997   Student_998        80.139645     2.400027         Pass
# 998   Student_999        88.069619     4.713490         Pass
# 999  Student_1000        84.695088     1.262504         Pass
#
# [1000 rows x 4 columns]

# %%
temp_df2 = df.iloc[:,[1,8,10,14]]
temp_df2
# Out:
#              name  attendance_rate  study_hours final_result
# 0       Student_1        94.660002     4.120192         Fail
# 1       Student_2        93.173227     2.886505         Pass
# 2       Student_3        98.631098     1.909926         Fail
# 3       Student_4        96.419620     1.664740         Pass
# 4       Student_5        91.332105     2.330918         Pass
# ..            ...              ...          ...          ...
# 995   Student_996        94.127440     2.212263         Fail
# 996   Student_997        86.911592     3.552898         Fail
# 997   Student_998        80.139645     2.400027         Pass
# 998   Student_999        88.069619     4.713490         Pass
# 999  Student_1000        84.695088     1.262504         Pass
#
# [1000 rows x 4 columns]

# %%
temp_df3 = df.iloc[:,[-1]] #TARGET COLUMN
temp_df4 = df.iloc[:,[3,4,5,6,7,8,10,11,13]]

# %%
# DIVIDING THE DATASET BASED ON A CONDITION

# %%
mask1 = df['internet_access'] == 'Yes'
mask2 = df['gender'] == 'Male'
df[mask1 & mask2]
# Out:
#     student_id         name gender  age  grade_level  math_score  \
# 4           S5    Student_5   Male   15            9          85
# 15         S16   Student_16   Male   17           10          83
# 20         S21   Student_21   Male   17           11          89
# 26         S27   Student_27   Male   16            9          74
# 38         S39   Student_39   Male   17           10          81
# ..         ...          ...    ...  ...          ...         ...
# 964       S965  Student_965   Male   15           11          70
# 971       S972  Student_972   Male   16           10          73
# 974       S975  Student_975   Male   17           12          96
# 975       S976  Student_976   Male   17           12          83
# 984       S985  Student_985   Male   17           12          68
#
#      reading_score  writing_score  attendance_rate parent_education  \
# 4               77             94        91.332105              PhD
# ...

# %%
df['final_result'].value_counts()
# Out:
# final_result
# Pass    517
# Fail    483
# Name: count, dtype: int64

# %% [markdown]
# PANDAS PLOT FUNCTION

# %%
df['gender'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['attendance_rate'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['study_hours'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['parent_education'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='parent_education'>

# %% [markdown]
# # SORTING VALUES

# %%
df.sort_values(['gender','reading_score'])
# Out:
#     student_id         name  gender  age  grade_level  math_score  \
# 317       S318  Student_318  Female   15            9          86
# 577       S578  Student_578  Female   15            9          69
# 754       S755  Student_755  Female   16           12          50
# 802       S803  Student_803  Female   16            9          51
# 968       S969  Student_969  Female   17           10          53
# ..         ...          ...     ...  ...          ...         ...
# 172       S173  Student_173   Other   16           11          68
# 174       S175  Student_175   Other   16           12          68
# 455       S456  Student_456   Other   17           10          61
# 542       S543  Student_543   Other   15           12          72
# 603       S604  Student_604   Other   17            9          87
#
#      reading_score  writing_score  attendance_rate parent_education  \
# 317             50             97        94.683025       Bachelor's
# ...

# %%
sectors_gender = df.groupby('gender')

# %%
sectors_gender.get_group('Male')
# Out:
#     student_id          name gender  age  grade_level  math_score  \
# 1           S2     Student_2   Male   17           12          99
# 4           S5     Student_5   Male   15            9          85
# 5           S6     Student_6   Male   17           11          61
# 12         S13    Student_13   Male   15           10          65
# 15         S16    Student_16   Male   17           10          83
# ..         ...           ...    ...  ...          ...         ...
# 984       S985   Student_985   Male   17           12          68
# 985       S986   Student_986   Male   17           12          86
# 986       S987   Student_987   Male   15           12          88
# 988       S989   Student_989   Male   16            9          57
# 999      S1000  Student_1000   Male   17            9          96
#
#      reading_score  writing_score  attendance_rate parent_education  \
# 1               70             91        93.173227       Bachelor's
# ...
